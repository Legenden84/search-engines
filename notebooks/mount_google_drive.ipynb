# %% [markdown]
# ### Install Colab

# %%
# %%capture
# %pip install google-colab

# %% [markdown]
# ### Imports

# %%
import shutil
from pathlib import Path
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Copy Colab CPU files to OneDrive

# %%
src = Path("/content/indexes")
dst = Path("/content/drive/MyDrive/se_project/indexes")

shutil.copytree(src, dst, dirs_exist_ok=True)

print(f"Copied indexes from {src} to {dst}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2116/1669994452.py in <cell line: 0>()
#       2 dst = Path("/content/drive/MyDrive/se_project/indexes")
#       3
# ----> 4 shutil.copytree(src, dst, dirs_exist_ok=True)
#       5
#       6 print(f"Copied indexes from {src} to {dst}")
#
# /usr/lib/python3.12/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     596     """
#     597     sys.audit("shutil.copytree", src, dst)
# --> 598     with os.scandir(src) as itr:
#     599         entries = list(itr)
#     600     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/indexes'

# %% [markdown]
# ### Injest PyTerrier Indexes into Colab CPU

# %%
src = Path("/content/drive/MyDrive/se_project/indexes")
dst = Path("/content/indexes")

if not src.exists():
    raise FileNotFoundError(f"Saved indexes not found at: {src}")

if dst.exists():
    print("Removed existing PyTerrier indexes")
    shutil.rmtree(dst)

shutil.copytree(src, dst)

print(f"Copied saved indexes from {src} to {dst}")
# Out:
# Copied saved indexes from /content/drive/MyDrive/se_project/indexes to /content/indexes
